# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
SPOTIPY_CLIENT_ID= '704df32a6a0f4d6abe98ac1b54014016'
SPOTIPY_CLIENT_SECRET='e50999b6c78842de8a222ef5eddbfed7'
#SPOTIPY_REDIRECT_URI='your-app-redirect-url'

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
sp.me
# Out:
# <bound method Spotify.me of <spotipy.client.Spotify object at 0x0000029390AA3100>>

# %% [markdown]
# ## Searching Artist

# %%
artist_name = 'Mitski'

# %%
artists = sp.search(q='artist:'+artist_name,type='artist', limit=20)

# %%
artists
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3AMitski&type=artist&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'followers': {'href': None, 'total': 3614696},
#     'genres': ['brooklyn indie', 'pop'],
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebafb309e27fdb45e093958f9c',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174afb309e27fdb45e093958f9c',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178afb309e27fdb45e093958f9c',
#       'width': 160}],
#     'name': 'Mitski',
#     'popularity': 79,
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JVoIrKHcvrkJBcYMLsPEm'},
#     'followers': {'href': None, 'total': 5},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1JVoIrKHcvrkJBcYMLsPEm',
#     'id': '1JVoIrKHcvrkJBcYMLsPEm',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27314fe63836581266c454ab48f',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0214fe63836581266c454ab48f',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485114fe63836581266c454ab48f',
#       'width': 64}],
#     'name': 'Xenitia Mitski',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:1JVoIrKHcvrkJBcYMLsPEm'}],
#   'limit': 20,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 2}}

# %%
artists['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#   'followers': {'href': None, 'total': 3614696},
#   'genres': ['brooklyn indie', 'pop'],
#   'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#   'id': '2uYWxilOVlUdk4oV9DvwqK',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5ebafb309e27fdb45e093958f9c',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab67616100005174afb309e27fdb45e093958f9c',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f178afb309e27fdb45e093958f9c',
#     'width': 160}],
#   'name': 'Mitski',
#   'popularity': 79,
#   'type': 'artist',
#   'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1JVoIrKHcvrkJBcYMLsPEm'},
#   'followers': {'href': None, 'total': 5},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/1JVoIrKHcvrkJBcYMLsPEm',
#   'id': '1JVoIrKHcvrkJBcYMLsPEm',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b27314fe63836581266c454ab48f',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e0214fe63836581266c454ab48f',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d0000485114fe63836581266c454ab48f',
#     'width': 64}],
#   'name': 'Xenitia Mitski',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:1JVoIrKHcvrkJBcYMLsPEm'}]

# %%
artists['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#  'followers': {'href': None, 'total': 3614696},
#  'genres': ['brooklyn indie', 'pop'],
#  'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#  'id': '2uYWxilOVlUdk4oV9DvwqK',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebafb309e27fdb45e093958f9c',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174afb309e27fdb45e093958f9c',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178afb309e27fdb45e093958f9c',
#    'width': 160}],
#  'name': 'Mitski',
#  'popularity': 79,
#  'type': 'artist',
#  'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}

# %%
artist_uri = artists['artists']['items'][0]['uri']
print(artist_uri)
# Out:
# spotify:artist:2uYWxilOVlUdk4oV9DvwqK

# %%
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:20]:
    print('track    : ' + track['name'])
    print('track id : ' + track['id'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Washing Machine Heart
# track id : 3jjsRKEsF42ccXf8kWR3nu
# audio    : https://p.scdn.co/mp3-preview/aa4073085d84897475a94110ddda62b20cf96310?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117
#
# track    : First Love / Late Spring
# track id : 3sslYZcFKtUvIEWN9lADgr
# audio    : https://p.scdn.co/mp3-preview/2ac96e91051f85acf58c73a64d1618c5a192a069?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273e90db8983ebd43b776694179
#
# track    : Nobody
# track id : 2P5yIMu2DNeMXTyOANKS6k
# audio    : https://p.scdn.co/mp3-preview/a96d01527158d7a70c6ef1b52e426ed690bbde9d?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117
#
# track    : Francis Forever
# track id : 5411TEB6tlzvuF5A4oyldr
# audio    : https://p.scdn.co/mp3-preview/208bb0df0656d48821e3978b8b5bb59dd8ae2353?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273e90db8983ebd43b776694179
#
# track    : Me and My Husband
# track id : 3pANfZVFdtuVnJsE6xa5Ox
# audio    : https://p.scdn.co/mp3-preview/09f082e7876a25f1c1ac9242d10ee9230be88853?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117
#
# track    : A Pearl
# track id : 7fd3aMiuwHWKsTdZafjOfZ
# audio    : https://p.scdn.co/mp3-preview/24f3b0bb224988882ce2f311e86688cf861883ea?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117
#
# track    : I Bet on Losing Dogs
# track id : 2Co0IjcLTSHMtodwD4gzfg
# audio    : https://p.scdn.co/mp3-preview/fd6ec52540c755e27293d1e9b1a7397206362680?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b27329eb9ad9b9af34bbb54eb053
#
# track    : Liquid Smooth
# track id : 3XCveEutwTaDiekRkkfdp9
# audio    : https://p.scdn.co/mp3-preview/c2afdb5d3ceb1513a50abf373e0547ec428a27e9?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b27318bbdba0da26e4ae050fb1b8
#
# track    : I Want You
# track id : 7FHj19QQigvMH1onMYRNLn
# audio    : https://p.scdn.co/mp3-preview/1441d8dd02c86559d37ecd4effda31003282f977?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b27334b5e51adeea6f1aa2285ce3
#
# track    : A Burning Hill
# track id : 6gz3orrUlKresI8GShSkdq
# audio    : https://p.scdn.co/mp3-preview/82432e603d1b93633707980b27b749232a86eb8d?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b27329eb9ad9b9af34bbb54eb053

# %%
results
# Out:
# {'tracks': [{'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#     'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#     'id': '42cH7mrkfljkqkxA2Ip9Xq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#       'width': 64}],
#     'name': 'Be the Cowboy',
#     'release_date': '2018-08-17',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 128198,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ5G1815012'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3jjsRKEsF42ccXf8kWR3nu'},
#    'href': 'https://api.spotify.com/v1/tracks/3jjsRKEsF42ccXf8kWR3nu',
#    'id': '3jjsRKEsF42ccXf8kWR3nu',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Washing Machine Heart',
#    'popularity': 83,
#    'preview_url': 'https://p.scdn.co/mp3-preview/aa4073085d84897475a94110ddda62b20cf96310?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 12,
#    'type': 'track',
#    'uri': 'spotify:track:3jjsRKEsF42ccXf8kWR3nu'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3I2KkX13lHXuYqfBjSOopo'},
#     'href': 'https://api.spotify.com/v1/albums/3I2KkX13lHXuYqfBjSOopo',
#     'id': '3I2KkX13lHXuYqfBjSOopo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e90db8983ebd43b776694179',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e90db8983ebd43b776694179',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e90db8983ebd43b776694179',
#       'width': 64}],
#     'name': 'Bury Me At Makeout Creek',
#     'release_date': '2014-11-11',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3I2KkX13lHXuYqfBjSOopo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 278640,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2B1511604'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3sslYZcFKtUvIEWN9lADgr'},
#    'href': 'https://api.spotify.com/v1/tracks/3sslYZcFKtUvIEWN9lADgr',
#    'id': '3sslYZcFKtUvIEWN9lADgr',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'First Love / Late Spring',
#    'popularity': 79,
#    'preview_url': 'https://p.scdn.co/mp3-preview/2ac96e91051f85acf58c73a64d1618c5a192a069?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:3sslYZcFKtUvIEWN9lADgr'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#     'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#     'id': '42cH7mrkfljkqkxA2Ip9Xq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#       'width': 64}],
#     'name': 'Be the Cowboy',
#     'release_date': '2018-08-17',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 193429,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ5G1815009'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2P5yIMu2DNeMXTyOANKS6k'},
#    'href': 'https://api.spotify.com/v1/tracks/2P5yIMu2DNeMXTyOANKS6k',
#    'id': '2P5yIMu2DNeMXTyOANKS6k',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Nobody',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/a96d01527158d7a70c6ef1b52e426ed690bbde9d?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:2P5yIMu2DNeMXTyOANKS6k'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/3I2KkX13lHXuYqfBjSOopo'},
#     'href': 'https://api.spotify.com/v1/albums/3I2KkX13lHXuYqfBjSOopo',
#     'id': '3I2KkX13lHXuYqfBjSOopo',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273e90db8983ebd43b776694179',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02e90db8983ebd43b776694179',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851e90db8983ebd43b776694179',
#       'width': 64}],
#     'name': 'Bury Me At Makeout Creek',
#     'release_date': '2014-11-11',
#     'release_date_precision': 'day',
#     'total_tracks': 10,
#     'type': 'album',
#     'uri': 'spotify:album:3I2KkX13lHXuYqfBjSOopo'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 149680,
#    'explicit': False,
#    'external_ids': {'isrc': 'USA2B1511605'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5411TEB6tlzvuF5A4oyldr'},
#    'href': 'https://api.spotify.com/v1/tracks/5411TEB6tlzvuF5A4oyldr',
#    'id': '5411TEB6tlzvuF5A4oyldr',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Francis Forever',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/208bb0df0656d48821e3978b8b5bb59dd8ae2353?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5411TEB6tlzvuF5A4oyldr'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#     'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#     'id': '42cH7mrkfljkqkxA2Ip9Xq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#       'width': 64}],
#     'name': 'Be the Cowboy',
#     'release_date': '2018-08-17',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 137141,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ5G1815007'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3pANfZVFdtuVnJsE6xa5Ox'},
#    'href': 'https://api.spotify.com/v1/tracks/3pANfZVFdtuVnJsE6xa5Ox',
#    'id': '3pANfZVFdtuVnJsE6xa5Ox',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Me and My Husband',
#    'popularity': 77,
#    'preview_url': 'https://p.scdn.co/mp3-preview/09f082e7876a25f1c1ac9242d10ee9230be88853?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:3pANfZVFdtuVnJsE6xa5Ox'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#     'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#     'id': '42cH7mrkfljkqkxA2Ip9Xq',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#       'width': 64}],
#     'name': 'Be the Cowboy',
#     'release_date': '2018-08-17',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 156145,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ5G1815004'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7fd3aMiuwHWKsTdZafjOfZ'},
#    'href': 'https://api.spotify.com/v1/tracks/7fd3aMiuwHWKsTdZafjOfZ',
#    'id': '7fd3aMiuwHWKsTdZafjOfZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'A Pearl',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/24f3b0bb224988882ce2f311e86688cf861883ea?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:7fd3aMiuwHWKsTdZafjOfZ'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Coa8Eb9SzjrkwWEom963Q'},
#     'href': 'https://api.spotify.com/v1/albums/4Coa8Eb9SzjrkwWEom963Q',
#     'id': '4Coa8Eb9SzjrkwWEom963Q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27329eb9ad9b9af34bbb54eb053',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0229eb9ad9b9af34bbb54eb053',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485129eb9ad9b9af34bbb54eb053',
#       'width': 64}],
#     'name': 'Puberty 2',
#     'release_date': '2016-06-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4Coa8Eb9SzjrkwWEom963Q'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 170240,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ5G1612306'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2Co0IjcLTSHMtodwD4gzfg'},
#    'href': 'https://api.spotify.com/v1/tracks/2Co0IjcLTSHMtodwD4gzfg',
#    'id': '2Co0IjcLTSHMtodwD4gzfg',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Bet on Losing Dogs',
#    'popularity': 75,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fd6ec52540c755e27293d1e9b1a7397206362680?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 6,
#    'type': 'track',
#    'uri': 'spotify:track:2Co0IjcLTSHMtodwD4gzfg'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/22MICAVuz34zzqm4Se5Lga'},
#     'href': 'https://api.spotify.com/v1/albums/22MICAVuz34zzqm4Se5Lga',
#     'id': '22MICAVuz34zzqm4Se5Lga',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27318bbdba0da26e4ae050fb1b8',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0218bbdba0da26e4ae050fb1b8',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485118bbdba0da26e4ae050fb1b8',
#       'width': 64}],
#     'name': 'Lush',
#     'release_date': '2012-01-31',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:22MICAVuz34zzqm4Se5Lga'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 169773,
#    'explicit': False,
#    'external_ids': {'isrc': 'USCGH1222956'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3XCveEutwTaDiekRkkfdp9'},
#    'href': 'https://api.spotify.com/v1/tracks/3XCveEutwTaDiekRkkfdp9',
#    'id': '3XCveEutwTaDiekRkkfdp9',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Liquid Smooth',
#    'popularity': 73,
#    'preview_url': 'https://p.scdn.co/mp3-preview/c2afdb5d3ceb1513a50abf373e0547ec428a27e9?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:3XCveEutwTaDiekRkkfdp9'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/7K4SuWzgUEweJScduBcC6f'},
#     'href': 'https://api.spotify.com/v1/albums/7K4SuWzgUEweJScduBcC6f',
#     'id': '7K4SuWzgUEweJScduBcC6f',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27334b5e51adeea6f1aa2285ce3',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0234b5e51adeea6f1aa2285ce3',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485134b5e51adeea6f1aa2285ce3',
#       'width': 64}],
#     'name': 'Retired from Sad, New Career in Business',
#     'release_date': '2013-08-01',
#     'release_date_precision': 'day',
#     'total_tracks': 9,
#     'type': 'album',
#     'uri': 'spotify:album:7K4SuWzgUEweJScduBcC6f'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 183792,
#    'explicit': False,
#    'external_ids': {'isrc': 'USHM81309666'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7FHj19QQigvMH1onMYRNLn'},
#    'href': 'https://api.spotify.com/v1/tracks/7FHj19QQigvMH1onMYRNLn',
#    'id': '7FHj19QQigvMH1onMYRNLn',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'I Want You',
#    'popularity': 72,
#    'preview_url': 'https://p.scdn.co/mp3-preview/1441d8dd02c86559d37ecd4effda31003282f977?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7FHj19QQigvMH1onMYRNLn'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#       'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#       'id': '2uYWxilOVlUdk4oV9DvwqK',
#       'name': 'Mitski',
#       'type': 'artist',
#       'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4Coa8Eb9SzjrkwWEom963Q'},
#     'href': 'https://api.spotify.com/v1/albums/4Coa8Eb9SzjrkwWEom963Q',
#     'id': '4Coa8Eb9SzjrkwWEom963Q',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b27329eb9ad9b9af34bbb54eb053',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e0229eb9ad9b9af34bbb54eb053',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d0000485129eb9ad9b9af34bbb54eb053',
#       'width': 64}],
#     'name': 'Puberty 2',
#     'release_date': '2016-06-17',
#     'release_date_precision': 'day',
#     'total_tracks': 11,
#     'type': 'album',
#     'uri': 'spotify:album:4Coa8Eb9SzjrkwWEom963Q'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'disc_number': 1,
#    'duration_ms': 109627,
#    'explicit': False,
#    'external_ids': {'isrc': 'USJ5G1612311'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6gz3orrUlKresI8GShSkdq'},
#    'href': 'https://api.spotify.com/v1/tracks/6gz3orrUlKresI8GShSkdq',
#    'id': '6gz3orrUlKresI8GShSkdq',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'A Burning Hill',
#    'popularity': 69,
#    'preview_url': 'https://p.scdn.co/mp3-preview/82432e603d1b93633707980b27b749232a86eb8d?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 11,
#    'type': 'track',
#    'uri': 'spotify:track:6gz3orrUlKresI8GShSkdq'}]}

# %%
results['tracks']
# Out:
# [{'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#    'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#    'id': '42cH7mrkfljkqkxA2Ip9Xq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#      'width': 64}],
#    'name': 'Be the Cowboy',
#    'release_date': '2018-08-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 128198,
#   'explicit': False,
#   'external_ids': {'isrc': 'USJ5G1815012'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3jjsRKEsF42ccXf8kWR3nu'},
#   'href': 'https://api.spotify.com/v1/tracks/3jjsRKEsF42ccXf8kWR3nu',
#   'id': '3jjsRKEsF42ccXf8kWR3nu',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Washing Machine Heart',
#   'popularity': 83,
#   'preview_url': 'https://p.scdn.co/mp3-preview/aa4073085d84897475a94110ddda62b20cf96310?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 12,
#   'type': 'track',
#   'uri': 'spotify:track:3jjsRKEsF42ccXf8kWR3nu'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3I2KkX13lHXuYqfBjSOopo'},
#    'href': 'https://api.spotify.com/v1/albums/3I2KkX13lHXuYqfBjSOopo',
#    'id': '3I2KkX13lHXuYqfBjSOopo',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e90db8983ebd43b776694179',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e90db8983ebd43b776694179',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e90db8983ebd43b776694179',
#      'width': 64}],
#    'name': 'Bury Me At Makeout Creek',
#    'release_date': '2014-11-11',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:3I2KkX13lHXuYqfBjSOopo'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 278640,
#   'explicit': False,
#   'external_ids': {'isrc': 'USA2B1511604'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3sslYZcFKtUvIEWN9lADgr'},
#   'href': 'https://api.spotify.com/v1/tracks/3sslYZcFKtUvIEWN9lADgr',
#   'id': '3sslYZcFKtUvIEWN9lADgr',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'First Love / Late Spring',
#   'popularity': 79,
#   'preview_url': 'https://p.scdn.co/mp3-preview/2ac96e91051f85acf58c73a64d1618c5a192a069?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:3sslYZcFKtUvIEWN9lADgr'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#    'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#    'id': '42cH7mrkfljkqkxA2Ip9Xq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#      'width': 64}],
#    'name': 'Be the Cowboy',
#    'release_date': '2018-08-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 193429,
#   'explicit': False,
#   'external_ids': {'isrc': 'USJ5G1815009'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2P5yIMu2DNeMXTyOANKS6k'},
#   'href': 'https://api.spotify.com/v1/tracks/2P5yIMu2DNeMXTyOANKS6k',
#   'id': '2P5yIMu2DNeMXTyOANKS6k',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Nobody',
#   'popularity': 78,
#   'preview_url': 'https://p.scdn.co/mp3-preview/a96d01527158d7a70c6ef1b52e426ed690bbde9d?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:2P5yIMu2DNeMXTyOANKS6k'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/3I2KkX13lHXuYqfBjSOopo'},
#    'href': 'https://api.spotify.com/v1/albums/3I2KkX13lHXuYqfBjSOopo',
#    'id': '3I2KkX13lHXuYqfBjSOopo',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273e90db8983ebd43b776694179',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02e90db8983ebd43b776694179',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851e90db8983ebd43b776694179',
#      'width': 64}],
#    'name': 'Bury Me At Makeout Creek',
#    'release_date': '2014-11-11',
#    'release_date_precision': 'day',
#    'total_tracks': 10,
#    'type': 'album',
#    'uri': 'spotify:album:3I2KkX13lHXuYqfBjSOopo'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 149680,
#   'explicit': False,
#   'external_ids': {'isrc': 'USA2B1511605'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5411TEB6tlzvuF5A4oyldr'},
#   'href': 'https://api.spotify.com/v1/tracks/5411TEB6tlzvuF5A4oyldr',
#   'id': '5411TEB6tlzvuF5A4oyldr',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Francis Forever',
#   'popularity': 78,
#   'preview_url': 'https://p.scdn.co/mp3-preview/208bb0df0656d48821e3978b8b5bb59dd8ae2353?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5411TEB6tlzvuF5A4oyldr'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#    'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#    'id': '42cH7mrkfljkqkxA2Ip9Xq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#      'width': 64}],
#    'name': 'Be the Cowboy',
#    'release_date': '2018-08-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 137141,
#   'explicit': False,
#   'external_ids': {'isrc': 'USJ5G1815007'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3pANfZVFdtuVnJsE6xa5Ox'},
#   'href': 'https://api.spotify.com/v1/tracks/3pANfZVFdtuVnJsE6xa5Ox',
#   'id': '3pANfZVFdtuVnJsE6xa5Ox',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Me and My Husband',
#   'popularity': 77,
#   'preview_url': 'https://p.scdn.co/mp3-preview/09f082e7876a25f1c1ac9242d10ee9230be88853?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:3pANfZVFdtuVnJsE6xa5Ox'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#    'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#    'id': '42cH7mrkfljkqkxA2Ip9Xq',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#      'width': 64}],
#    'name': 'Be the Cowboy',
#    'release_date': '2018-08-17',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 156145,
#   'explicit': False,
#   'external_ids': {'isrc': 'USJ5G1815004'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7fd3aMiuwHWKsTdZafjOfZ'},
#   'href': 'https://api.spotify.com/v1/tracks/7fd3aMiuwHWKsTdZafjOfZ',
#   'id': '7fd3aMiuwHWKsTdZafjOfZ',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'A Pearl',
#   'popularity': 75,
#   'preview_url': 'https://p.scdn.co/mp3-preview/24f3b0bb224988882ce2f311e86688cf861883ea?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:7fd3aMiuwHWKsTdZafjOfZ'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4Coa8Eb9SzjrkwWEom963Q'},
#    'href': 'https://api.spotify.com/v1/albums/4Coa8Eb9SzjrkwWEom963Q',
#    'id': '4Coa8Eb9SzjrkwWEom963Q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27329eb9ad9b9af34bbb54eb053',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0229eb9ad9b9af34bbb54eb053',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485129eb9ad9b9af34bbb54eb053',
#      'width': 64}],
#    'name': 'Puberty 2',
#    'release_date': '2016-06-17',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4Coa8Eb9SzjrkwWEom963Q'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 170240,
#   'explicit': False,
#   'external_ids': {'isrc': 'USJ5G1612306'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2Co0IjcLTSHMtodwD4gzfg'},
#   'href': 'https://api.spotify.com/v1/tracks/2Co0IjcLTSHMtodwD4gzfg',
#   'id': '2Co0IjcLTSHMtodwD4gzfg',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'I Bet on Losing Dogs',
#   'popularity': 75,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fd6ec52540c755e27293d1e9b1a7397206362680?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 6,
#   'type': 'track',
#   'uri': 'spotify:track:2Co0IjcLTSHMtodwD4gzfg'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/22MICAVuz34zzqm4Se5Lga'},
#    'href': 'https://api.spotify.com/v1/albums/22MICAVuz34zzqm4Se5Lga',
#    'id': '22MICAVuz34zzqm4Se5Lga',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27318bbdba0da26e4ae050fb1b8',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0218bbdba0da26e4ae050fb1b8',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485118bbdba0da26e4ae050fb1b8',
#      'width': 64}],
#    'name': 'Lush',
#    'release_date': '2012-01-31',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:22MICAVuz34zzqm4Se5Lga'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 169773,
#   'explicit': False,
#   'external_ids': {'isrc': 'USCGH1222956'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3XCveEutwTaDiekRkkfdp9'},
#   'href': 'https://api.spotify.com/v1/tracks/3XCveEutwTaDiekRkkfdp9',
#   'id': '3XCveEutwTaDiekRkkfdp9',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Liquid Smooth',
#   'popularity': 73,
#   'preview_url': 'https://p.scdn.co/mp3-preview/c2afdb5d3ceb1513a50abf373e0547ec428a27e9?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:3XCveEutwTaDiekRkkfdp9'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7K4SuWzgUEweJScduBcC6f'},
#    'href': 'https://api.spotify.com/v1/albums/7K4SuWzgUEweJScduBcC6f',
#    'id': '7K4SuWzgUEweJScduBcC6f',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27334b5e51adeea6f1aa2285ce3',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0234b5e51adeea6f1aa2285ce3',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485134b5e51adeea6f1aa2285ce3',
#      'width': 64}],
#    'name': 'Retired from Sad, New Career in Business',
#    'release_date': '2013-08-01',
#    'release_date_precision': 'day',
#    'total_tracks': 9,
#    'type': 'album',
#    'uri': 'spotify:album:7K4SuWzgUEweJScduBcC6f'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 183792,
#   'explicit': False,
#   'external_ids': {'isrc': 'USHM81309666'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7FHj19QQigvMH1onMYRNLn'},
#   'href': 'https://api.spotify.com/v1/tracks/7FHj19QQigvMH1onMYRNLn',
#   'id': '7FHj19QQigvMH1onMYRNLn',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'I Want You',
#   'popularity': 72,
#   'preview_url': 'https://p.scdn.co/mp3-preview/1441d8dd02c86559d37ecd4effda31003282f977?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:7FHj19QQigvMH1onMYRNLn'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#      'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#      'id': '2uYWxilOVlUdk4oV9DvwqK',
#      'name': 'Mitski',
#      'type': 'artist',
#      'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4Coa8Eb9SzjrkwWEom963Q'},
#    'href': 'https://api.spotify.com/v1/albums/4Coa8Eb9SzjrkwWEom963Q',
#    'id': '4Coa8Eb9SzjrkwWEom963Q',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b27329eb9ad9b9af34bbb54eb053',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e0229eb9ad9b9af34bbb54eb053',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d0000485129eb9ad9b9af34bbb54eb053',
#      'width': 64}],
#    'name': 'Puberty 2',
#    'release_date': '2016-06-17',
#    'release_date_precision': 'day',
#    'total_tracks': 11,
#    'type': 'album',
#    'uri': 'spotify:album:4Coa8Eb9SzjrkwWEom963Q'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'disc_number': 1,
#   'duration_ms': 109627,
#   'explicit': False,
#   'external_ids': {'isrc': 'USJ5G1612311'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6gz3orrUlKresI8GShSkdq'},
#   'href': 'https://api.spotify.com/v1/tracks/6gz3orrUlKresI8GShSkdq',
#   'id': '6gz3orrUlKresI8GShSkdq',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'A Burning Hill',
#   'popularity': 69,
#   'preview_url': 'https://p.scdn.co/mp3-preview/82432e603d1b93633707980b27b749232a86eb8d?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 11,
#   'type': 'track',
#   'uri': 'spotify:track:6gz3orrUlKresI8GShSkdq'}]

# %%
len(results['tracks'])
# Out:
# 10

# %%
results['tracks'][0]
# Out:
# {'album': {'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#     'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#     'id': '2uYWxilOVlUdk4oV9DvwqK',
#     'name': 'Mitski',
#     'type': 'artist',
#     'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/42cH7mrkfljkqkxA2Ip9Xq'},
#   'href': 'https://api.spotify.com/v1/albums/42cH7mrkfljkqkxA2Ip9Xq',
#   'id': '42cH7mrkfljkqkxA2Ip9Xq',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273c428f67b4a9b7e1114dfc117',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02c428f67b4a9b7e1114dfc117',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851c428f67b4a9b7e1114dfc117',
#     'width': 64}],
#   'name': 'Be the Cowboy',
#   'release_date': '2018-08-17',
#   'release_date_precision': 'day',
#   'total_tracks': 14,
#   'type': 'album',
#   'uri': 'spotify:album:42cH7mrkfljkqkxA2Ip9Xq'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/2uYWxilOVlUdk4oV9DvwqK'},
#    'href': 'https://api.spotify.com/v1/artists/2uYWxilOVlUdk4oV9DvwqK',
#    'id': '2uYWxilOVlUdk4oV9DvwqK',
#    'name': 'Mitski',
#    'type': 'artist',
#    'uri': 'spotify:artist:2uYWxilOVlUdk4oV9DvwqK'}],
#  'disc_number': 1,
#  'duration_ms': 128198,
#  'explicit': False,
#  'external_ids': {'isrc': 'USJ5G1815012'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/3jjsRKEsF42ccXf8kWR3nu'},
#  'href': 'https://api.spotify.com/v1/tracks/3jjsRKEsF42ccXf8kWR3nu',
#  'id': '3jjsRKEsF42ccXf8kWR3nu',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Washing Machine Heart',
#  'popularity': 83,
#  'preview_url': 'https://p.scdn.co/mp3-preview/aa4073085d84897475a94110ddda62b20cf96310?cid=704df32a6a0f4d6abe98ac1b54014016',
#  'track_number': 12,
#  'type': 'track',
#  'uri': 'spotify:track:3jjsRKEsF42ccXf8kWR3nu'}

# %%
print(results['tracks'][0]['id'])
print(results['tracks'][0]['popularity'])
print(results['tracks'][0]['name'])
print(results['tracks'][0]['album']['release_date'])
# Out:
# 3jjsRKEsF42ccXf8kWR3nu
# 83
# Washing Machine Heart
# 2018-08-17

# %%
track_result = []
for i, item in enumerate(results['tracks']):
#     track = item['album']
    track_id = item['id']
    track_name = item['name']
    popularity = item['popularity']
    track_result.append((i, artist_name, track['name'], track_id, track_name, item['album']['release_date'], popularity))

# %%
track_result
# Out:
# [(0,
#   'Mitski',
#   'A Burning Hill',
#   '3jjsRKEsF42ccXf8kWR3nu',
#   'Washing Machine Heart',
#   '2018-08-17',
#   83),
#  (1,
#   'Mitski',
#   'A Burning Hill',
#   '3sslYZcFKtUvIEWN9lADgr',
#   'First Love / Late Spring',
#   '2014-11-11',
#   79),
#  (2,
#   'Mitski',
#   'A Burning Hill',
#   '2P5yIMu2DNeMXTyOANKS6k',
#   'Nobody',
#   '2018-08-17',
#   78),
#  (3,
#   'Mitski',
#   'A Burning Hill',
#   '5411TEB6tlzvuF5A4oyldr',
#   'Francis Forever',
#   '2014-11-11',
#   78),
#  (4,
#   'Mitski',
#   'A Burning Hill',
#   '3pANfZVFdtuVnJsE6xa5Ox',
#   'Me and My Husband',
#   '2018-08-17',
#   77),
#  (5,
#   'Mitski',
#   'A Burning Hill',
#   '7fd3aMiuwHWKsTdZafjOfZ',
#   'A Pearl',
#   '2018-08-17',
#   75),
#  (6,
#   'Mitski',
#   'A Burning Hill',
#   '2Co0IjcLTSHMtodwD4gzfg',
#   'I Bet on Losing Dogs',
#   '2016-06-17',
#   75),
#  (7,
#   'Mitski',
#   'A Burning Hill',
#   '3XCveEutwTaDiekRkkfdp9',
#   'Liquid Smooth',
#   '2012-01-31',
#   73),
#  (8,
#   'Mitski',
#   'A Burning Hill',
#   '7FHj19QQigvMH1onMYRNLn',
#   'I Want You',
#   '2013-08-01',
#   72),
#  (9,
#   'Mitski',
#   'A Burning Hill',
#   '6gz3orrUlKresI8GShSkdq',
#   'A Burning Hill',
#   '2016-06-17',
#   69)]

# %%
track_df = pd.DataFrame(track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity'))

# %%
track_df
# Out:
#    Item  Artist      Album Name                      Id  \
# 0     0  Mitski  A Burning Hill  3jjsRKEsF42ccXf8kWR3nu
# 1     1  Mitski  A Burning Hill  3sslYZcFKtUvIEWN9lADgr
# 2     2  Mitski  A Burning Hill  2P5yIMu2DNeMXTyOANKS6k
# 3     3  Mitski  A Burning Hill  5411TEB6tlzvuF5A4oyldr
# 4     4  Mitski  A Burning Hill  3pANfZVFdtuVnJsE6xa5Ox
# 5     5  Mitski  A Burning Hill  7fd3aMiuwHWKsTdZafjOfZ
# 6     6  Mitski  A Burning Hill  2Co0IjcLTSHMtodwD4gzfg
# 7     7  Mitski  A Burning Hill  3XCveEutwTaDiekRkkfdp9
# 8     8  Mitski  A Burning Hill  7FHj19QQigvMH1onMYRNLn
# 9     9  Mitski  A Burning Hill  6gz3orrUlKresI8GShSkdq
#
#                   Song Name Release Date  Popularity
# 0     Washing Machine Heart   2018-08-17          83
# 1  First Love / Late Spring   2014-11-11          79
# 2                    Nobody   2018-08-17          78
# 3           Francis Forever   2014-11-11          78
# 4         Me and My Husband   2018-08-17          77
# 5                   A Pearl   2018-08-17          75
# 6      I Bet on Losing Dogs   2016-06-17          75
# 7             Liquid Smooth   2012-01-31          73
# 8                I Want You   2013-08-01          72
# 9            A Burning Hill   2016-06-17          69

# %%
features_df = pd.DataFrame()
for id in track_df['Id'].iteritems():
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    local_features = pd.DataFrame(audio_features, index=[0])
    features_df = features_df.append(local_features)

# %%
features_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.613   0.822    9    -4.087     1       0.0260      0.009200
# 0         0.445   0.543    0    -8.196     1       0.0272      0.000825
# 0         0.398   0.717    0    -5.253     1       0.0398      0.070000
# 0         0.535   0.448    2    -9.167     1       0.0279      0.002620
# 0         0.497   0.638    1    -5.310     1       0.0274      0.046700
# 0         0.295   0.637    8    -4.043     1       0.0288      0.049600
# 0         0.398   0.493    9    -9.561     1       0.0303      0.003470
# 0         0.424   0.342    7    -9.469     0       0.0339      0.838000
# 0         0.339   0.292    3   -11.294     1       0.0348      0.514000
# 0         0.462   0.191    2   -14.993     1       0.0374      0.770000
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0          0.506000    0.4290   0.5670  105.997  audio_features
# 0          0.013700    0.2020   0.1020   99.963  audio_features
# 0          0.000000    0.0850   0.4870  117.296  audio_features
# 0          0.000019    0.1150   0.3200  101.986  audio_features
# 0          0.000000    0.3850   0.7700  172.010  audio_features
# 0          0.023600    0.1120   0.2210   84.551  audio_features
# 0          0.000157    0.1060   0.4120   82.048  audio_features
# 0          0.000000    0.1360   0.1240   76.235  audio_features
# 0          0.000000    0.0713   0.0655  131.702  audio_features
# 0          0.002640    0.1070   0.0996  132.034  audio_features
#
#                        id                                   uri  \
# 0  3jjsRKEsF42ccXf8kWR3nu  spotify:track:3jjsRKEsF42ccXf8kWR3nu
# 0  3sslYZcFKtUvIEWN9lADgr  spotify:track:3sslYZcFKtUvIEWN9lADgr
# 0  2P5yIMu2DNeMXTyOANKS6k  spotify:track:2P5yIMu2DNeMXTyOANKS6k
# 0  5411TEB6tlzvuF5A4oyldr  spotify:track:5411TEB6tlzvuF5A4oyldr
# 0  3pANfZVFdtuVnJsE6xa5Ox  spotify:track:3pANfZVFdtuVnJsE6xa5Ox
# 0  7fd3aMiuwHWKsTdZafjOfZ  spotify:track:7fd3aMiuwHWKsTdZafjOfZ
# 0  2Co0IjcLTSHMtodwD4gzfg  spotify:track:2Co0IjcLTSHMtodwD4gzfg
# 0  3XCveEutwTaDiekRkkfdp9  spotify:track:3XCveEutwTaDiekRkkfdp9
# 0  7FHj19QQigvMH1onMYRNLn  spotify:track:7FHj19QQigvMH1onMYRNLn
# 0  6gz3orrUlKresI8GShSkdq  spotify:track:6gz3orrUlKresI8GShSkdq
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3jjsRKEsF42c...
# 0  https://api.spotify.com/v1/tracks/3sslYZcFKtUv...
# 0  https://api.spotify.com/v1/tracks/2P5yIMu2DNeM...
# 0  https://api.spotify.com/v1/tracks/5411TEB6tlzv...
# 0  https://api.spotify.com/v1/tracks/3pANfZVFdtuV...
# 0  https://api.spotify.com/v1/tracks/7fd3aMiuwHWK...
# 0  https://api.spotify.com/v1/tracks/2Co0IjcLTSHM...
# 0  https://api.spotify.com/v1/tracks/3XCveEutwTaD...
# 0  https://api.spotify.com/v1/tracks/7FHj19QQigvM...
# 0  https://api.spotify.com/v1/tracks/6gz3orrUlKre...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3jjs...       128199
# 0  https://api.spotify.com/v1/audio-analysis/3ssl...       278640
# 0  https://api.spotify.com/v1/audio-analysis/2P5y...       193429
# 0  https://api.spotify.com/v1/audio-analysis/5411...       149680
# 0  https://api.spotify.com/v1/audio-analysis/3pAN...       137142
# 0  https://api.spotify.com/v1/audio-analysis/7fd3...       156146
# 0  https://api.spotify.com/v1/audio-analysis/2Co0...       170240
# 0  https://api.spotify.com/v1/audio-analysis/3XCv...       169773
# 0  https://api.spotify.com/v1/audio-analysis/7FHj...       183792
# 0  https://api.spotify.com/v1/audio-analysis/6gz3...       109628
#
#    time_signature
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               3
# 0               1

# %%
final_df = track_df.merge(features_df, left_on="Id", right_on="id")

# %%
final_df
# Out:
#    Item  Artist      Album Name                      Id  \
# 0     0  Mitski  A Burning Hill  3jjsRKEsF42ccXf8kWR3nu
# 1     1  Mitski  A Burning Hill  3sslYZcFKtUvIEWN9lADgr
# 2     2  Mitski  A Burning Hill  2P5yIMu2DNeMXTyOANKS6k
# 3     3  Mitski  A Burning Hill  5411TEB6tlzvuF5A4oyldr
# 4     4  Mitski  A Burning Hill  3pANfZVFdtuVnJsE6xa5Ox
# 5     5  Mitski  A Burning Hill  7fd3aMiuwHWKsTdZafjOfZ
# 6     6  Mitski  A Burning Hill  2Co0IjcLTSHMtodwD4gzfg
# 7     7  Mitski  A Burning Hill  3XCveEutwTaDiekRkkfdp9
# 8     8  Mitski  A Burning Hill  7FHj19QQigvMH1onMYRNLn
# 9     9  Mitski  A Burning Hill  6gz3orrUlKresI8GShSkdq
#
#                   Song Name Release Date  Popularity  danceability  energy  \
# 0     Washing Machine Heart   2018-08-17          83         0.613   0.822
# 1  First Love / Late Spring   2014-11-11          79         0.445   0.543
# 2                    Nobody   2018-08-17          78         0.398   0.717
# 3           Francis Forever   2014-11-11          78         0.535   0.448
# 4         Me and My Husband   2018-08-17          77         0.497   0.638
# 5                   A Pearl   2018-08-17          75         0.295   0.637
# 6      I Bet on Losing Dogs   2016-06-17          75         0.398   0.493
# 7             Liquid Smooth   2012-01-31          73         0.424   0.342
# 8                I Want You   2013-08-01          72         0.339   0.292
# 9            A Burning Hill   2016-06-17          69         0.462   0.191
#
#    key  ...  liveness  valence    tempo            type  \
# 0    9  ...    0.4290   0.5670  105.997  audio_features
# 1    0  ...    0.2020   0.1020   99.963  audio_features
# 2    0  ...    0.0850   0.4870  117.296  audio_features
# 3    2  ...    0.1150   0.3200  101.986  audio_features
# 4    1  ...    0.3850   0.7700  172.010  audio_features
# 5    8  ...    0.1120   0.2210   84.551  audio_features
# 6    9  ...    0.1060   0.4120   82.048  audio_features
# 7    7  ...    0.1360   0.1240   76.235  audio_features
# 8    3  ...    0.0713   0.0655  131.702  audio_features
# 9    2  ...    0.1070   0.0996  132.034  audio_features
#
#                        id                                   uri  \
# 0  3jjsRKEsF42ccXf8kWR3nu  spotify:track:3jjsRKEsF42ccXf8kWR3nu
# 1  3sslYZcFKtUvIEWN9lADgr  spotify:track:3sslYZcFKtUvIEWN9lADgr
# 2  2P5yIMu2DNeMXTyOANKS6k  spotify:track:2P5yIMu2DNeMXTyOANKS6k
# 3  5411TEB6tlzvuF5A4oyldr  spotify:track:5411TEB6tlzvuF5A4oyldr
# 4  3pANfZVFdtuVnJsE6xa5Ox  spotify:track:3pANfZVFdtuVnJsE6xa5Ox
# 5  7fd3aMiuwHWKsTdZafjOfZ  spotify:track:7fd3aMiuwHWKsTdZafjOfZ
# 6  2Co0IjcLTSHMtodwD4gzfg  spotify:track:2Co0IjcLTSHMtodwD4gzfg
# 7  3XCveEutwTaDiekRkkfdp9  spotify:track:3XCveEutwTaDiekRkkfdp9
# 8  7FHj19QQigvMH1onMYRNLn  spotify:track:7FHj19QQigvMH1onMYRNLn
# 9  6gz3orrUlKresI8GShSkdq  spotify:track:6gz3orrUlKresI8GShSkdq
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/3jjsRKEsF42c...
# 1  https://api.spotify.com/v1/tracks/3sslYZcFKtUv...
# 2  https://api.spotify.com/v1/tracks/2P5yIMu2DNeM...
# 3  https://api.spotify.com/v1/tracks/5411TEB6tlzv...
# 4  https://api.spotify.com/v1/tracks/3pANfZVFdtuV...
# 5  https://api.spotify.com/v1/tracks/7fd3aMiuwHWK...
# 6  https://api.spotify.com/v1/tracks/2Co0IjcLTSHM...
# 7  https://api.spotify.com/v1/tracks/3XCveEutwTaD...
# 8  https://api.spotify.com/v1/tracks/7FHj19QQigvM...
# 9  https://api.spotify.com/v1/tracks/6gz3orrUlKre...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/3jjs...      128199
# 1  https://api.spotify.com/v1/audio-analysis/3ssl...      278640
# 2  https://api.spotify.com/v1/audio-analysis/2P5y...      193429
# 3  https://api.spotify.com/v1/audio-analysis/5411...      149680
# 4  https://api.spotify.com/v1/audio-analysis/3pAN...      137142
# 5  https://api.spotify.com/v1/audio-analysis/7fd3...      156146
# 6  https://api.spotify.com/v1/audio-analysis/2Co0...      170240
# 7  https://api.spotify.com/v1/audio-analysis/3XCv...      169773
# 8  https://api.spotify.com/v1/audio-analysis/7FHj...      183792
# 9  https://api.spotify.com/v1/audio-analysis/6gz3...      109628
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4
# 6              4
# 7              4
# 8              3
# 9              1
#
# [10 rows x 25 columns]

# %%
final_df.to_csv('SpotifyMitskiSongFeatures.csv', index=False)

# %% [markdown]
# ## Song Feature Comparisons

# %%
final_df_sorted = final_df.sort_values(by=['Popularity'], ascending=False)

# %%
feature_name = "danceability"

# %%
df_plot = final_df_sorted[['Artist', 'Album Name', 'Song Name', 'Release Date', 'Popularity', f'{feature_name}']]

# %%
df_plot
# Out:
#    Artist      Album Name                 Song Name Release Date  Popularity  \
# 0  Mitski  A Burning Hill     Washing Machine Heart   2018-08-17          83
# 1  Mitski  A Burning Hill  First Love / Late Spring   2014-11-11          79
# 2  Mitski  A Burning Hill                    Nobody   2018-08-17          78
# 3  Mitski  A Burning Hill           Francis Forever   2014-11-11          78
# 4  Mitski  A Burning Hill         Me and My Husband   2018-08-17          77
# 5  Mitski  A Burning Hill                   A Pearl   2018-08-17          75
# 6  Mitski  A Burning Hill      I Bet on Losing Dogs   2016-06-17          75
# 7  Mitski  A Burning Hill             Liquid Smooth   2012-01-31          73
# 8  Mitski  A Burning Hill                I Want You   2013-08-01          72
# 9  Mitski  A Burning Hill            A Burning Hill   2016-06-17          69
#
#    danceability
# 0         0.613
# 1         0.445
# 2         0.398
# 3         0.535
# 4         0.497
# 5         0.295
# 6         0.398
# 7         0.424
# 8         0.339
# 9         0.462

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(15, 6), facecolor=(.9, .9, .9))
    
x = df_plot['Song Name']
y = df_plot[feature_name]
s = df_plot['Popularity']*10
    
# color_labels = reco_df['explicit'].unique()
# rgb_values = sns.color_palette("Set1", 8)
# color_map = dict(zip(color_labels, rgb_values))

plt.scatter(x, y, s, alpha=0.7, c=df_plot[feature_name])
plt.xticks(rotation=90)
plt.legend()
# show the graph
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#installing altair before use
#pip install altair
#pip show altair

# %%
import altair as alt

# %%
alt.Chart(df_plot).mark_circle().encode(
alt.X('Popularity', scale=alt.Scale(zero=False)), y=f'{feature_name}', color=alt.Color('Popularity', scale=alt.Scale(zero=False)), 
size=alt.value(200), tooltip=['Popularity', f'{feature_name}', 'Song Name', 'Album Name'])
# Out:
# alt.Chart(...)
