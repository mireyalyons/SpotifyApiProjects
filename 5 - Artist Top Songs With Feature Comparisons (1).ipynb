# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
SPOTIPY_CLIENT_ID= '704df32a6a0f4d6abe98ac1b54014016'
SPOTIPY_CLIENT_SECRET='e50999b6c78842de8a222ef5eddbfed7'
#SPOTIPY_REDIRECT_URI='your-app-redirect-url'

# %%
auth_manager = SpotifyClientCredentials(client_id=SPOTIPY_CLIENT_ID, client_secret=SPOTIPY_CLIENT_SECRET)
sp = spotipy.Spotify(auth_manager=auth_manager)

# %%
sp.me
# Out:
# <bound method Spotify.me of <spotipy.client.Spotify object at 0x000001A5EBBC01F0>>

# %% [markdown]
# ## Searching Artist

# %%
artist_name = 'Eyedress'

# %%
artists = sp.search(q='artist:'+artist_name,type='artist', limit=10)

# %%
artists
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=artist%3AEyedress&type=artist&offset=0&limit=10',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'followers': {'href': None, 'total': 875163},
#     'genres': ['noise pop'],
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5eb13a6e324c8ad5437b4bb4c5d',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab6761610000517413a6e324c8ad5437b4bb4c5d',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f17813a6e324c8ad5437b4bb4c5d',
#       'width': 160}],
#     'name': 'Eyedress',
#     'popularity': 71,
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/1252YQB89G6AODtbh1IxNL'},
#     'followers': {'href': None, 'total': 3},
#     'genres': [],
#     'href': 'https://api.spotify.com/v1/artists/1252YQB89G6AODtbh1IxNL',
#     'id': '1252YQB89G6AODtbh1IxNL',
#     'images': [],
#     'name': 'Eyedress and Ankhten Brown',
#     'popularity': 0,
#     'type': 'artist',
#     'uri': 'spotify:artist:1252YQB89G6AODtbh1IxNL'}],
#   'limit': 10,
#   'next': None,
#   'offset': 0,
#   'previous': None,
#   'total': 2}}

# %%
artists['artists']['items']
# Out:
# [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#   'followers': {'href': None, 'total': 875163},
#   'genres': ['noise pop'],
#   'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#   'id': '3XxNRirzbjfLdDli06zMaB',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab6761610000e5eb13a6e324c8ad5437b4bb4c5d',
#     'width': 640},
#    {'height': 320,
#     'url': 'https://i.scdn.co/image/ab6761610000517413a6e324c8ad5437b4bb4c5d',
#     'width': 320},
#    {'height': 160,
#     'url': 'https://i.scdn.co/image/ab6761610000f17813a6e324c8ad5437b4bb4c5d',
#     'width': 160}],
#   'name': 'Eyedress',
#   'popularity': 71,
#   'type': 'artist',
#   'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#  {'external_urls': {'spotify': 'https://open.spotify.com/artist/1252YQB89G6AODtbh1IxNL'},
#   'followers': {'href': None, 'total': 3},
#   'genres': [],
#   'href': 'https://api.spotify.com/v1/artists/1252YQB89G6AODtbh1IxNL',
#   'id': '1252YQB89G6AODtbh1IxNL',
#   'images': [],
#   'name': 'Eyedress and Ankhten Brown',
#   'popularity': 0,
#   'type': 'artist',
#   'uri': 'spotify:artist:1252YQB89G6AODtbh1IxNL'}]

# %%
artists['artists']['items'][0]
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#  'followers': {'href': None, 'total': 875163},
#  'genres': ['noise pop'],
#  'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#  'id': '3XxNRirzbjfLdDli06zMaB',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5eb13a6e324c8ad5437b4bb4c5d',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab6761610000517413a6e324c8ad5437b4bb4c5d',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f17813a6e324c8ad5437b4bb4c5d',
#    'width': 160}],
#  'name': 'Eyedress',
#  'popularity': 71,
#  'type': 'artist',
#  'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}

# %%
artist_uri = artists['artists']['items'][0]['uri']
print(artist_uri)
# Out:
# spotify:artist:3XxNRirzbjfLdDli06zMaB

# %%
results = sp.artist_top_tracks(artist_uri)

for track in results['tracks'][:10]:
    print('track    : ' + track['name'])
    print('track id : ' + track['id'])
    print('audio    : ' + track['preview_url'])
    print('cover art: ' + track['album']['images'][0]['url'])
    print()
# Out:
# track    : Jealous
# track id : 1aXV8GrmQLvgoFtBPERP7E
# audio    : https://p.scdn.co/mp3-preview/8f8aea269c6b4189f047cd672f8bd4f84cf4c71f?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273157bf6b6c046bbb3e7907eb0
#
# track    : Something About You
# track id : 6RiiSy9GzSwiyDEJDiMuKe
# audio    : https://p.scdn.co/mp3-preview/5f872d2e88f9042bac457b21adbd7d07109f4819?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b2735088565ff98ae4246ba44255
#
# track    : Romantic Lover
# track id : 7s5VQqrjBtrBgZL4pEa46S
# audio    : https://p.scdn.co/mp3-preview/fd4569acfa83791e9a7733890eefb2ca8527228c?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417
#
# track    : Cocaine Sunday
# track id : 5HzrX4aKVfb1NQCsaqf6R0
# audio    : https://p.scdn.co/mp3-preview/45c5623bae1da5c7ac11b810539a81389dc42809?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273fa26588f468545b76a2124ac
#
# track    : On Fye
# track id : 6qLQ0K5jkOB0QrbDwNmKg9
# audio    : https://p.scdn.co/mp3-preview/e9d183976dd4c6e88c86913069fd8a65c0e4382c?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273df8d0d7b1283f95b3f991373
#
# track    : Kiss Me Like It's the First Time
# track id : 2n87qFKfPcqRPNfNH4TiAM
# audio    : https://p.scdn.co/mp3-preview/cd2756fe84611a25b60bbe88bdfb46ffb0780cfb?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417
#
# track    : Body Dysmorphia
# track id : 3QVa3D6QaQy0b0foOAYDuy
# audio    : https://p.scdn.co/mp3-preview/104d8bb4d9709d6c0004fc18cdbfbb017a062121?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b2735088565ff98ae4246ba44255
#
# track    : Can I See You Tonight?
# track id : 1cpmW4m6NVcAI33ZDEGwjZ
# audio    : https://p.scdn.co/mp3-preview/156e095e99819b85d4d5c64374a58b18f2abe6b0?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417
#
# track    : Separation Anxiety
# track id : 2XycvTajCfgJFNYDY1JVTG
# audio    : https://p.scdn.co/mp3-preview/15b072c62ea884412e7798e26e1edc5984bc56bf?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b273d240aa6e5d25c57fd477ef67
#
# track    : Let's Skip to the Wedding
# track id : 6DfZhqra01cpWIH5VluN2q
# audio    : https://p.scdn.co/mp3-preview/3dbc3ab52284c71182a2bd103f4c2ca21563522f?cid=704df32a6a0f4d6abe98ac1b54014016
# cover art: https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417

# %%
results
# Out:
# {'tracks': [{'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4keJsdw9XhEvimhIgXmtO1'},
#     'href': 'https://api.spotify.com/v1/albums/4keJsdw9XhEvimhIgXmtO1',
#     'id': '4keJsdw9XhEvimhIgXmtO1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273157bf6b6c046bbb3e7907eb0',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02157bf6b6c046bbb3e7907eb0',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851157bf6b6c046bbb3e7907eb0',
#       'width': 64}],
#     'name': 'Jealous',
#     'release_date': '2019-12-06',
#     'release_date_precision': 'day',
#     'total_tracks': 3,
#     'type': 'album',
#     'uri': 'spotify:album:4keJsdw9XhEvimhIgXmtO1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 122338,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF1900115'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1aXV8GrmQLvgoFtBPERP7E'},
#    'href': 'https://api.spotify.com/v1/tracks/1aXV8GrmQLvgoFtBPERP7E',
#    'id': '1aXV8GrmQLvgoFtBPERP7E',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Jealous',
#    'popularity': 82,
#    'preview_url': 'https://p.scdn.co/mp3-preview/8f8aea269c6b4189f047cd672f8bd4f84cf4c71f?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:1aXV8GrmQLvgoFtBPERP7E'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0QB8JzlX70ame6G972aEF1'},
#     'href': 'https://api.spotify.com/v1/albums/0QB8JzlX70ame6G972aEF1',
#     'id': '0QB8JzlX70ame6G972aEF1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735088565ff98ae4246ba44255',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025088565ff98ae4246ba44255',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515088565ff98ae4246ba44255',
#       'width': 64}],
#     'name': 'Mulholland Drive',
#     'release_date': '2021-08-27',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:0QB8JzlX70ame6G972aEF1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/34me8hAxavRmcDIwhxa3b7'},
#      'href': 'https://api.spotify.com/v1/artists/34me8hAxavRmcDIwhxa3b7',
#      'id': '34me8hAxavRmcDIwhxa3b7',
#      'name': 'Dent May',
#      'type': 'artist',
#      'uri': 'spotify:artist:34me8hAxavRmcDIwhxa3b7'}],
#    'disc_number': 1,
#    'duration_ms': 153312,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF2000174'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6RiiSy9GzSwiyDEJDiMuKe'},
#    'href': 'https://api.spotify.com/v1/tracks/6RiiSy9GzSwiyDEJDiMuKe',
#    'id': '6RiiSy9GzSwiyDEJDiMuKe',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Something About You',
#    'popularity': 78,
#    'preview_url': 'https://p.scdn.co/mp3-preview/5f872d2e88f9042bac457b21adbd7d07109f4819?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:6RiiSy9GzSwiyDEJDiMuKe'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#     'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#     'id': '04uOXDWUgZmTps35RqDBg4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#       'width': 64}],
#     'name': "Let's Skip to the Wedding",
#     'release_date': '2020-08-07',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 86739,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF2000011'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/7s5VQqrjBtrBgZL4pEa46S'},
#    'href': 'https://api.spotify.com/v1/tracks/7s5VQqrjBtrBgZL4pEa46S',
#    'id': '7s5VQqrjBtrBgZL4pEa46S',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Romantic Lover',
#    'popularity': 76,
#    'preview_url': 'https://p.scdn.co/mp3-preview/fd4569acfa83791e9a7733890eefb2ca8527228c?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 5,
#    'type': 'track',
#    'uri': 'spotify:track:7s5VQqrjBtrBgZL4pEa46S'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/2nzPJxgiC7qfdYBBfJiHfj'},
#     'href': 'https://api.spotify.com/v1/albums/2nzPJxgiC7qfdYBBfJiHfj',
#     'id': '2nzPJxgiC7qfdYBBfJiHfj',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273fa26588f468545b76a2124ac',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02fa26588f468545b76a2124ac',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851fa26588f468545b76a2124ac',
#       'width': 64}],
#     'name': 'Sensitive G',
#     'release_date': '2018-11-16',
#     'release_date_precision': 'day',
#     'total_tracks': 20,
#     'type': 'album',
#     'uri': 'spotify:album:2nzPJxgiC7qfdYBBfJiHfj'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 168739,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF1800060'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5HzrX4aKVfb1NQCsaqf6R0'},
#    'href': 'https://api.spotify.com/v1/tracks/5HzrX4aKVfb1NQCsaqf6R0',
#    'id': '5HzrX4aKVfb1NQCsaqf6R0',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Cocaine Sunday',
#    'popularity': 67,
#    'preview_url': 'https://p.scdn.co/mp3-preview/45c5623bae1da5c7ac11b810539a81389dc42809?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:5HzrX4aKVfb1NQCsaqf6R0'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1jsT4oqnLcCax2grWbuhL6'},
#       'href': 'https://api.spotify.com/v1/artists/1jsT4oqnLcCax2grWbuhL6',
#       'id': '1jsT4oqnLcCax2grWbuhL6',
#       'name': 'The Simps',
#       'type': 'artist',
#       'uri': 'spotify:artist:1jsT4oqnLcCax2grWbuhL6'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#      {'external_urls': {'spotify': 'https://open.spotify.com/artist/26j38hvhD7PjC0a4EqdaSn'},
#       'href': 'https://api.spotify.com/v1/artists/26j38hvhD7PjC0a4EqdaSn',
#       'id': '26j38hvhD7PjC0a4EqdaSn',
#       'name': 'zzzahara',
#       'type': 'artist',
#       'uri': 'spotify:artist:26j38hvhD7PjC0a4EqdaSn'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/4s8ALi238WwLW0zphoLeF6'},
#     'href': 'https://api.spotify.com/v1/albums/4s8ALi238WwLW0zphoLeF6',
#     'id': '4s8ALi238WwLW0zphoLeF6',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273df8d0d7b1283f95b3f991373',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02df8d0d7b1283f95b3f991373',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851df8d0d7b1283f95b3f991373',
#       'width': 64}],
#     'name': 'Siblings',
#     'release_date': '2022-02-14',
#     'release_date_precision': 'day',
#     'total_tracks': 14,
#     'type': 'album',
#     'uri': 'spotify:album:4s8ALi238WwLW0zphoLeF6'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1jsT4oqnLcCax2grWbuhL6'},
#      'href': 'https://api.spotify.com/v1/artists/1jsT4oqnLcCax2grWbuhL6',
#      'id': '1jsT4oqnLcCax2grWbuhL6',
#      'name': 'The Simps',
#      'type': 'artist',
#      'uri': 'spotify:artist:1jsT4oqnLcCax2grWbuhL6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/26j38hvhD7PjC0a4EqdaSn'},
#      'href': 'https://api.spotify.com/v1/artists/26j38hvhD7PjC0a4EqdaSn',
#      'id': '26j38hvhD7PjC0a4EqdaSn',
#      'name': 'zzzahara',
#      'type': 'artist',
#      'uri': 'spotify:artist:26j38hvhD7PjC0a4EqdaSn'}],
#    'disc_number': 1,
#    'duration_ms': 127000,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF2000123'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6qLQ0K5jkOB0QrbDwNmKg9'},
#    'href': 'https://api.spotify.com/v1/tracks/6qLQ0K5jkOB0QrbDwNmKg9',
#    'id': '6qLQ0K5jkOB0QrbDwNmKg9',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'On Fye',
#    'popularity': 62,
#    'preview_url': 'https://p.scdn.co/mp3-preview/e9d183976dd4c6e88c86913069fd8a65c0e4382c?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 7,
#    'type': 'track',
#    'uri': 'spotify:track:6qLQ0K5jkOB0QrbDwNmKg9'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#     'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#     'id': '04uOXDWUgZmTps35RqDBg4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#       'width': 64}],
#     'name': "Let's Skip to the Wedding",
#     'release_date': '2020-08-07',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 176283,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF2000021'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2n87qFKfPcqRPNfNH4TiAM'},
#    'href': 'https://api.spotify.com/v1/tracks/2n87qFKfPcqRPNfNH4TiAM',
#    'id': '2n87qFKfPcqRPNfNH4TiAM',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Kiss Me Like It's the First Time",
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/cd2756fe84611a25b60bbe88bdfb46ffb0780cfb?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 18,
#    'type': 'track',
#    'uri': 'spotify:track:2n87qFKfPcqRPNfNH4TiAM'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/0QB8JzlX70ame6G972aEF1'},
#     'href': 'https://api.spotify.com/v1/albums/0QB8JzlX70ame6G972aEF1',
#     'id': '0QB8JzlX70ame6G972aEF1',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2735088565ff98ae4246ba44255',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e025088565ff98ae4246ba44255',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048515088565ff98ae4246ba44255',
#       'width': 64}],
#     'name': 'Mulholland Drive',
#     'release_date': '2021-08-27',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:0QB8JzlX70ame6G972aEF1'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 125085,
#    'explicit': True,
#    'external_ids': {'isrc': 'GBMYF2100015'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/3QVa3D6QaQy0b0foOAYDuy'},
#    'href': 'https://api.spotify.com/v1/tracks/3QVa3D6QaQy0b0foOAYDuy',
#    'id': '3QVa3D6QaQy0b0foOAYDuy',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Body Dysmorphia',
#    'popularity': 58,
#    'preview_url': 'https://p.scdn.co/mp3-preview/104d8bb4d9709d6c0004fc18cdbfbb017a062121?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 9,
#    'type': 'track',
#    'uri': 'spotify:track:3QVa3D6QaQy0b0foOAYDuy'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#     'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#     'id': '04uOXDWUgZmTps35RqDBg4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#       'width': 64}],
#     'name': "Let's Skip to the Wedding",
#     'release_date': '2020-08-07',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 157575,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF2000010'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/1cpmW4m6NVcAI33ZDEGwjZ'},
#    'href': 'https://api.spotify.com/v1/tracks/1cpmW4m6NVcAI33ZDEGwjZ',
#    'id': '1cpmW4m6NVcAI33ZDEGwjZ',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Can I See You Tonight?',
#    'popularity': 57,
#    'preview_url': 'https://p.scdn.co/mp3-preview/156e095e99819b85d4d5c64374a58b18f2abe6b0?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 4,
#    'type': 'track',
#    'uri': 'spotify:track:1cpmW4m6NVcAI33ZDEGwjZ'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/1KkpoRciTIH31x5ZiSb1UP'},
#     'href': 'https://api.spotify.com/v1/albums/1KkpoRciTIH31x5ZiSb1UP',
#     'id': '1KkpoRciTIH31x5ZiSb1UP',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b273d240aa6e5d25c57fd477ef67',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e02d240aa6e5d25c57fd477ef67',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d00004851d240aa6e5d25c57fd477ef67',
#       'width': 64}],
#     'name': 'Manila Ice',
#     'release_date': '2017-05-12',
#     'release_date_precision': 'day',
#     'total_tracks': 15,
#     'type': 'album',
#     'uri': 'spotify:album:1KkpoRciTIH31x5ZiSb1UP'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 227467,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF1600068'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/2XycvTajCfgJFNYDY1JVTG'},
#    'href': 'https://api.spotify.com/v1/tracks/2XycvTajCfgJFNYDY1JVTG',
#    'id': '2XycvTajCfgJFNYDY1JVTG',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Separation Anxiety',
#    'popularity': 56,
#    'preview_url': 'https://p.scdn.co/mp3-preview/15b072c62ea884412e7798e26e1edc5984bc56bf?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 3,
#    'type': 'track',
#    'uri': 'spotify:track:2XycvTajCfgJFNYDY1JVTG'},
#   {'album': {'album_type': 'album',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#       'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#       'id': '3XxNRirzbjfLdDli06zMaB',
#       'name': 'Eyedress',
#       'type': 'artist',
#       'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#     'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#     'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#     'id': '04uOXDWUgZmTps35RqDBg4',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#       'width': 640},
#      {'height': 300,
#       'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#       'width': 300},
#      {'height': 64,
#       'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#       'width': 64}],
#     'name': "Let's Skip to the Wedding",
#     'release_date': '2020-08-07',
#     'release_date_precision': 'day',
#     'total_tracks': 19,
#     'type': 'album',
#     'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'disc_number': 1,
#    'duration_ms': 98209,
#    'explicit': False,
#    'external_ids': {'isrc': 'GBMYF1900118'},
#    'external_urls': {'spotify': 'https://open.spotify.com/track/6DfZhqra01cpWIH5VluN2q'},
#    'href': 'https://api.spotify.com/v1/tracks/6DfZhqra01cpWIH5VluN2q',
#    'id': '6DfZhqra01cpWIH5VluN2q',
#    'is_local': False,
#    'is_playable': True,
#    'name': "Let's Skip to the Wedding",
#    'popularity': 55,
#    'preview_url': 'https://p.scdn.co/mp3-preview/3dbc3ab52284c71182a2bd103f4c2ca21563522f?cid=704df32a6a0f4d6abe98ac1b54014016',
#    'track_number': 1,
#    'type': 'track',
#    'uri': 'spotify:track:6DfZhqra01cpWIH5VluN2q'}]}

# %%
results['tracks']
# Out:
# [{'album': {'album_type': 'single',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4keJsdw9XhEvimhIgXmtO1'},
#    'href': 'https://api.spotify.com/v1/albums/4keJsdw9XhEvimhIgXmtO1',
#    'id': '4keJsdw9XhEvimhIgXmtO1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273157bf6b6c046bbb3e7907eb0',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02157bf6b6c046bbb3e7907eb0',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851157bf6b6c046bbb3e7907eb0',
#      'width': 64}],
#    'name': 'Jealous',
#    'release_date': '2019-12-06',
#    'release_date_precision': 'day',
#    'total_tracks': 3,
#    'type': 'album',
#    'uri': 'spotify:album:4keJsdw9XhEvimhIgXmtO1'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 122338,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF1900115'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1aXV8GrmQLvgoFtBPERP7E'},
#   'href': 'https://api.spotify.com/v1/tracks/1aXV8GrmQLvgoFtBPERP7E',
#   'id': '1aXV8GrmQLvgoFtBPERP7E',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Jealous',
#   'popularity': 82,
#   'preview_url': 'https://p.scdn.co/mp3-preview/8f8aea269c6b4189f047cd672f8bd4f84cf4c71f?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:1aXV8GrmQLvgoFtBPERP7E'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0QB8JzlX70ame6G972aEF1'},
#    'href': 'https://api.spotify.com/v1/albums/0QB8JzlX70ame6G972aEF1',
#    'id': '0QB8JzlX70ame6G972aEF1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735088565ff98ae4246ba44255',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025088565ff98ae4246ba44255',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515088565ff98ae4246ba44255',
#      'width': 64}],
#    'name': 'Mulholland Drive',
#    'release_date': '2021-08-27',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:0QB8JzlX70ame6G972aEF1'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/34me8hAxavRmcDIwhxa3b7'},
#     'href': 'https://api.spotify.com/v1/artists/34me8hAxavRmcDIwhxa3b7',
#     'id': '34me8hAxavRmcDIwhxa3b7',
#     'name': 'Dent May',
#     'type': 'artist',
#     'uri': 'spotify:artist:34me8hAxavRmcDIwhxa3b7'}],
#   'disc_number': 1,
#   'duration_ms': 153312,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF2000174'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6RiiSy9GzSwiyDEJDiMuKe'},
#   'href': 'https://api.spotify.com/v1/tracks/6RiiSy9GzSwiyDEJDiMuKe',
#   'id': '6RiiSy9GzSwiyDEJDiMuKe',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Something About You',
#   'popularity': 78,
#   'preview_url': 'https://p.scdn.co/mp3-preview/5f872d2e88f9042bac457b21adbd7d07109f4819?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:6RiiSy9GzSwiyDEJDiMuKe'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#    'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#    'id': '04uOXDWUgZmTps35RqDBg4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#      'width': 64}],
#    'name': "Let's Skip to the Wedding",
#    'release_date': '2020-08-07',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 86739,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF2000011'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/7s5VQqrjBtrBgZL4pEa46S'},
#   'href': 'https://api.spotify.com/v1/tracks/7s5VQqrjBtrBgZL4pEa46S',
#   'id': '7s5VQqrjBtrBgZL4pEa46S',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Romantic Lover',
#   'popularity': 76,
#   'preview_url': 'https://p.scdn.co/mp3-preview/fd4569acfa83791e9a7733890eefb2ca8527228c?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 5,
#   'type': 'track',
#   'uri': 'spotify:track:7s5VQqrjBtrBgZL4pEa46S'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/2nzPJxgiC7qfdYBBfJiHfj'},
#    'href': 'https://api.spotify.com/v1/albums/2nzPJxgiC7qfdYBBfJiHfj',
#    'id': '2nzPJxgiC7qfdYBBfJiHfj',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273fa26588f468545b76a2124ac',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02fa26588f468545b76a2124ac',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851fa26588f468545b76a2124ac',
#      'width': 64}],
#    'name': 'Sensitive G',
#    'release_date': '2018-11-16',
#    'release_date_precision': 'day',
#    'total_tracks': 20,
#    'type': 'album',
#    'uri': 'spotify:album:2nzPJxgiC7qfdYBBfJiHfj'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 168739,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF1800060'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/5HzrX4aKVfb1NQCsaqf6R0'},
#   'href': 'https://api.spotify.com/v1/tracks/5HzrX4aKVfb1NQCsaqf6R0',
#   'id': '5HzrX4aKVfb1NQCsaqf6R0',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Cocaine Sunday',
#   'popularity': 67,
#   'preview_url': 'https://p.scdn.co/mp3-preview/45c5623bae1da5c7ac11b810539a81389dc42809?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:5HzrX4aKVfb1NQCsaqf6R0'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1jsT4oqnLcCax2grWbuhL6'},
#      'href': 'https://api.spotify.com/v1/artists/1jsT4oqnLcCax2grWbuhL6',
#      'id': '1jsT4oqnLcCax2grWbuhL6',
#      'name': 'The Simps',
#      'type': 'artist',
#      'uri': 'spotify:artist:1jsT4oqnLcCax2grWbuhL6'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#     {'external_urls': {'spotify': 'https://open.spotify.com/artist/26j38hvhD7PjC0a4EqdaSn'},
#      'href': 'https://api.spotify.com/v1/artists/26j38hvhD7PjC0a4EqdaSn',
#      'id': '26j38hvhD7PjC0a4EqdaSn',
#      'name': 'zzzahara',
#      'type': 'artist',
#      'uri': 'spotify:artist:26j38hvhD7PjC0a4EqdaSn'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/4s8ALi238WwLW0zphoLeF6'},
#    'href': 'https://api.spotify.com/v1/albums/4s8ALi238WwLW0zphoLeF6',
#    'id': '4s8ALi238WwLW0zphoLeF6',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273df8d0d7b1283f95b3f991373',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02df8d0d7b1283f95b3f991373',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851df8d0d7b1283f95b3f991373',
#      'width': 64}],
#    'name': 'Siblings',
#    'release_date': '2022-02-14',
#    'release_date_precision': 'day',
#    'total_tracks': 14,
#    'type': 'album',
#    'uri': 'spotify:album:4s8ALi238WwLW0zphoLeF6'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/1jsT4oqnLcCax2grWbuhL6'},
#     'href': 'https://api.spotify.com/v1/artists/1jsT4oqnLcCax2grWbuhL6',
#     'id': '1jsT4oqnLcCax2grWbuhL6',
#     'name': 'The Simps',
#     'type': 'artist',
#     'uri': 'spotify:artist:1jsT4oqnLcCax2grWbuhL6'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'},
#    {'external_urls': {'spotify': 'https://open.spotify.com/artist/26j38hvhD7PjC0a4EqdaSn'},
#     'href': 'https://api.spotify.com/v1/artists/26j38hvhD7PjC0a4EqdaSn',
#     'id': '26j38hvhD7PjC0a4EqdaSn',
#     'name': 'zzzahara',
#     'type': 'artist',
#     'uri': 'spotify:artist:26j38hvhD7PjC0a4EqdaSn'}],
#   'disc_number': 1,
#   'duration_ms': 127000,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF2000123'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6qLQ0K5jkOB0QrbDwNmKg9'},
#   'href': 'https://api.spotify.com/v1/tracks/6qLQ0K5jkOB0QrbDwNmKg9',
#   'id': '6qLQ0K5jkOB0QrbDwNmKg9',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'On Fye',
#   'popularity': 62,
#   'preview_url': 'https://p.scdn.co/mp3-preview/e9d183976dd4c6e88c86913069fd8a65c0e4382c?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 7,
#   'type': 'track',
#   'uri': 'spotify:track:6qLQ0K5jkOB0QrbDwNmKg9'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#    'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#    'id': '04uOXDWUgZmTps35RqDBg4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#      'width': 64}],
#    'name': "Let's Skip to the Wedding",
#    'release_date': '2020-08-07',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 176283,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF2000021'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2n87qFKfPcqRPNfNH4TiAM'},
#   'href': 'https://api.spotify.com/v1/tracks/2n87qFKfPcqRPNfNH4TiAM',
#   'id': '2n87qFKfPcqRPNfNH4TiAM',
#   'is_local': False,
#   'is_playable': True,
#   'name': "Kiss Me Like It's the First Time",
#   'popularity': 58,
#   'preview_url': 'https://p.scdn.co/mp3-preview/cd2756fe84611a25b60bbe88bdfb46ffb0780cfb?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 18,
#   'type': 'track',
#   'uri': 'spotify:track:2n87qFKfPcqRPNfNH4TiAM'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/0QB8JzlX70ame6G972aEF1'},
#    'href': 'https://api.spotify.com/v1/albums/0QB8JzlX70ame6G972aEF1',
#    'id': '0QB8JzlX70ame6G972aEF1',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2735088565ff98ae4246ba44255',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e025088565ff98ae4246ba44255',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048515088565ff98ae4246ba44255',
#      'width': 64}],
#    'name': 'Mulholland Drive',
#    'release_date': '2021-08-27',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:0QB8JzlX70ame6G972aEF1'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 125085,
#   'explicit': True,
#   'external_ids': {'isrc': 'GBMYF2100015'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/3QVa3D6QaQy0b0foOAYDuy'},
#   'href': 'https://api.spotify.com/v1/tracks/3QVa3D6QaQy0b0foOAYDuy',
#   'id': '3QVa3D6QaQy0b0foOAYDuy',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Body Dysmorphia',
#   'popularity': 58,
#   'preview_url': 'https://p.scdn.co/mp3-preview/104d8bb4d9709d6c0004fc18cdbfbb017a062121?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 9,
#   'type': 'track',
#   'uri': 'spotify:track:3QVa3D6QaQy0b0foOAYDuy'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#    'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#    'id': '04uOXDWUgZmTps35RqDBg4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#      'width': 64}],
#    'name': "Let's Skip to the Wedding",
#    'release_date': '2020-08-07',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 157575,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF2000010'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/1cpmW4m6NVcAI33ZDEGwjZ'},
#   'href': 'https://api.spotify.com/v1/tracks/1cpmW4m6NVcAI33ZDEGwjZ',
#   'id': '1cpmW4m6NVcAI33ZDEGwjZ',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Can I See You Tonight?',
#   'popularity': 57,
#   'preview_url': 'https://p.scdn.co/mp3-preview/156e095e99819b85d4d5c64374a58b18f2abe6b0?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 4,
#   'type': 'track',
#   'uri': 'spotify:track:1cpmW4m6NVcAI33ZDEGwjZ'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/1KkpoRciTIH31x5ZiSb1UP'},
#    'href': 'https://api.spotify.com/v1/albums/1KkpoRciTIH31x5ZiSb1UP',
#    'id': '1KkpoRciTIH31x5ZiSb1UP',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273d240aa6e5d25c57fd477ef67',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02d240aa6e5d25c57fd477ef67',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d00004851d240aa6e5d25c57fd477ef67',
#      'width': 64}],
#    'name': 'Manila Ice',
#    'release_date': '2017-05-12',
#    'release_date_precision': 'day',
#    'total_tracks': 15,
#    'type': 'album',
#    'uri': 'spotify:album:1KkpoRciTIH31x5ZiSb1UP'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 227467,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF1600068'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/2XycvTajCfgJFNYDY1JVTG'},
#   'href': 'https://api.spotify.com/v1/tracks/2XycvTajCfgJFNYDY1JVTG',
#   'id': '2XycvTajCfgJFNYDY1JVTG',
#   'is_local': False,
#   'is_playable': True,
#   'name': 'Separation Anxiety',
#   'popularity': 56,
#   'preview_url': 'https://p.scdn.co/mp3-preview/15b072c62ea884412e7798e26e1edc5984bc56bf?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 3,
#   'type': 'track',
#   'uri': 'spotify:track:2XycvTajCfgJFNYDY1JVTG'},
#  {'album': {'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#      'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#      'id': '3XxNRirzbjfLdDli06zMaB',
#      'name': 'Eyedress',
#      'type': 'artist',
#      'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/04uOXDWUgZmTps35RqDBg4'},
#    'href': 'https://api.spotify.com/v1/albums/04uOXDWUgZmTps35RqDBg4',
#    'id': '04uOXDWUgZmTps35RqDBg4',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b2732a960aa5c84973aa3622f417',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e022a960aa5c84973aa3622f417',
#      'width': 300},
#     {'height': 64,
#      'url': 'https://i.scdn.co/image/ab67616d000048512a960aa5c84973aa3622f417',
#      'width': 64}],
#    'name': "Let's Skip to the Wedding",
#    'release_date': '2020-08-07',
#    'release_date_precision': 'day',
#    'total_tracks': 19,
#    'type': 'album',
#    'uri': 'spotify:album:04uOXDWUgZmTps35RqDBg4'},
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'disc_number': 1,
#   'duration_ms': 98209,
#   'explicit': False,
#   'external_ids': {'isrc': 'GBMYF1900118'},
#   'external_urls': {'spotify': 'https://open.spotify.com/track/6DfZhqra01cpWIH5VluN2q'},
#   'href': 'https://api.spotify.com/v1/tracks/6DfZhqra01cpWIH5VluN2q',
#   'id': '6DfZhqra01cpWIH5VluN2q',
#   'is_local': False,
#   'is_playable': True,
#   'name': "Let's Skip to the Wedding",
#   'popularity': 55,
#   'preview_url': 'https://p.scdn.co/mp3-preview/3dbc3ab52284c71182a2bd103f4c2ca21563522f?cid=704df32a6a0f4d6abe98ac1b54014016',
#   'track_number': 1,
#   'type': 'track',
#   'uri': 'spotify:track:6DfZhqra01cpWIH5VluN2q'}]

# %%
len(results['tracks'])
# Out:
# 10

# %%
results['tracks'][0]
# Out:
# {'album': {'album_type': 'single',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#     'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#     'id': '3XxNRirzbjfLdDli06zMaB',
#     'name': 'Eyedress',
#     'type': 'artist',
#     'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/4keJsdw9XhEvimhIgXmtO1'},
#   'href': 'https://api.spotify.com/v1/albums/4keJsdw9XhEvimhIgXmtO1',
#   'id': '4keJsdw9XhEvimhIgXmtO1',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273157bf6b6c046bbb3e7907eb0',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02157bf6b6c046bbb3e7907eb0',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851157bf6b6c046bbb3e7907eb0',
#     'width': 64}],
#   'name': 'Jealous',
#   'release_date': '2019-12-06',
#   'release_date_precision': 'day',
#   'total_tracks': 3,
#   'type': 'album',
#   'uri': 'spotify:album:4keJsdw9XhEvimhIgXmtO1'},
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/3XxNRirzbjfLdDli06zMaB'},
#    'href': 'https://api.spotify.com/v1/artists/3XxNRirzbjfLdDli06zMaB',
#    'id': '3XxNRirzbjfLdDli06zMaB',
#    'name': 'Eyedress',
#    'type': 'artist',
#    'uri': 'spotify:artist:3XxNRirzbjfLdDli06zMaB'}],
#  'disc_number': 1,
#  'duration_ms': 122338,
#  'explicit': False,
#  'external_ids': {'isrc': 'GBMYF1900115'},
#  'external_urls': {'spotify': 'https://open.spotify.com/track/1aXV8GrmQLvgoFtBPERP7E'},
#  'href': 'https://api.spotify.com/v1/tracks/1aXV8GrmQLvgoFtBPERP7E',
#  'id': '1aXV8GrmQLvgoFtBPERP7E',
#  'is_local': False,
#  'is_playable': True,
#  'name': 'Jealous',
#  'popularity': 82,
#  'preview_url': 'https://p.scdn.co/mp3-preview/8f8aea269c6b4189f047cd672f8bd4f84cf4c71f?cid=704df32a6a0f4d6abe98ac1b54014016',
#  'track_number': 1,
#  'type': 'track',
#  'uri': 'spotify:track:1aXV8GrmQLvgoFtBPERP7E'}

# %%
print(results['tracks'][0]['id'])
print(results['tracks'][0]['popularity'])
print(results['tracks'][0]['name'])
print(results['tracks'][0]['album']['release_date'])
# Out:
# 1aXV8GrmQLvgoFtBPERP7E
# 82
# Jealous
# 2019-12-06

# %%
track_result = []
for i, item in enumerate(results['tracks']):
#     track = item['album']
    track_id = item['id']
    track_name = item['name']
    popularity = item['popularity']
    track_result.append((i, artist_name, track['name'], track_id, track_name, item['album']['release_date'], popularity))

# %%
track_result
# Out:
# [(0,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '1aXV8GrmQLvgoFtBPERP7E',
#   'Jealous',
#   '2019-12-06',
#   82),
#  (1,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '6RiiSy9GzSwiyDEJDiMuKe',
#   'Something About You',
#   '2021-08-27',
#   78),
#  (2,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '7s5VQqrjBtrBgZL4pEa46S',
#   'Romantic Lover',
#   '2020-08-07',
#   76),
#  (3,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '5HzrX4aKVfb1NQCsaqf6R0',
#   'Cocaine Sunday',
#   '2018-11-16',
#   67),
#  (4,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '6qLQ0K5jkOB0QrbDwNmKg9',
#   'On Fye',
#   '2022-02-14',
#   62),
#  (5,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '2n87qFKfPcqRPNfNH4TiAM',
#   "Kiss Me Like It's the First Time",
#   '2020-08-07',
#   58),
#  (6,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '3QVa3D6QaQy0b0foOAYDuy',
#   'Body Dysmorphia',
#   '2021-08-27',
#   58),
#  (7,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '1cpmW4m6NVcAI33ZDEGwjZ',
#   'Can I See You Tonight?',
#   '2020-08-07',
#   57),
#  (8,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '2XycvTajCfgJFNYDY1JVTG',
#   'Separation Anxiety',
#   '2017-05-12',
#   56),
#  (9,
#   'Eyedress',
#   "Let's Skip to the Wedding",
#   '6DfZhqra01cpWIH5VluN2q',
#   "Let's Skip to the Wedding",
#   '2020-08-07',
#   55)]

# %%
track_df = pd.DataFrame(track_result, index=None, columns=('Item', 'Artist', 'Album Name', 'Id', 'Song Name', 'Release Date', 'Popularity'))

# %%
track_df
# Out:
#    Item    Artist                 Album Name                      Id  \
# 0     0  Eyedress  Let's Skip to the Wedding  1aXV8GrmQLvgoFtBPERP7E
# 1     1  Eyedress  Let's Skip to the Wedding  6RiiSy9GzSwiyDEJDiMuKe
# 2     2  Eyedress  Let's Skip to the Wedding  7s5VQqrjBtrBgZL4pEa46S
# 3     3  Eyedress  Let's Skip to the Wedding  5HzrX4aKVfb1NQCsaqf6R0
# 4     4  Eyedress  Let's Skip to the Wedding  6qLQ0K5jkOB0QrbDwNmKg9
# 5     5  Eyedress  Let's Skip to the Wedding  2n87qFKfPcqRPNfNH4TiAM
# 6     6  Eyedress  Let's Skip to the Wedding  3QVa3D6QaQy0b0foOAYDuy
# 7     7  Eyedress  Let's Skip to the Wedding  1cpmW4m6NVcAI33ZDEGwjZ
# 8     8  Eyedress  Let's Skip to the Wedding  2XycvTajCfgJFNYDY1JVTG
# 9     9  Eyedress  Let's Skip to the Wedding  6DfZhqra01cpWIH5VluN2q
#
#                           Song Name Release Date  Popularity
# 0                           Jealous   2019-12-06          82
# 1               Something About You   2021-08-27          78
# 2                    Romantic Lover   2020-08-07          76
# 3                    Cocaine Sunday   2018-11-16          67
# 4                            On Fye   2022-02-14          62
# 5  Kiss Me Like It's the First Time   2020-08-07          58
# 6                   Body Dysmorphia   2021-08-27          58
# 7            Can I See You Tonight?   2020-08-07          57
# 8                Separation Anxiety   2017-05-12          56
# 9         Let's Skip to the Wedding   2020-08-07          55

# %%
features_df = pd.DataFrame()
for id in track_df['Id'].iteritems():
    track_id = id[1]
    audio_features = sp.audio_features(track_id)
    local_features = pd.DataFrame(audio_features, index=[0])
    features_df = features_df.append(local_features)

# %%
features_df
# Out:
#    danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.474   0.921    9   -10.431     0       0.0457       0.00491
# 0         0.648   0.781    9    -8.736     0       0.0271       0.03320
# 0         0.658   0.447    9    -9.299     0       0.0869       0.70100
# 0         0.544   0.765    4    -6.491     1       0.0259       0.00818
# 0         0.484   0.804    1    -5.884     1       0.0286       0.01110
# 0         0.636   0.593   11   -10.269     0       0.0364       0.07550
# 0         0.495   0.662   11    -7.899     1       0.0391       0.04930
# 0         0.444   0.615    9   -10.620     0       0.0508       0.23700
# 0         0.423   0.760    3    -8.193     0       0.0784       0.12400
# 0         0.454   0.966    9    -6.972     0       0.0441       0.02130
#
#    instrumentalness  liveness  valence    tempo            type  \
# 0           0.85000    0.4760    0.696   93.010  audio_features
# 0           0.01300    0.3050    0.822  133.417  audio_features
# 0           0.92400    0.1980    0.538  184.316  audio_features
# 0           0.82100    0.1500    0.429  153.916  audio_features
# 0           0.11600    0.2680    0.802   92.425  audio_features
# 0           0.85900    0.0454    0.223  113.007  audio_features
# 0           0.90900    0.1190    0.966  165.209  audio_features
# 0           0.89800    0.1150    0.613  197.880  audio_features
# 0           0.00768    0.1100    0.519  164.096  audio_features
# 0           0.03400    0.0580    0.643  148.210  audio_features
#
#                        id                                   uri  \
# 0  1aXV8GrmQLvgoFtBPERP7E  spotify:track:1aXV8GrmQLvgoFtBPERP7E
# 0  6RiiSy9GzSwiyDEJDiMuKe  spotify:track:6RiiSy9GzSwiyDEJDiMuKe
# 0  7s5VQqrjBtrBgZL4pEa46S  spotify:track:7s5VQqrjBtrBgZL4pEa46S
# 0  5HzrX4aKVfb1NQCsaqf6R0  spotify:track:5HzrX4aKVfb1NQCsaqf6R0
# 0  6qLQ0K5jkOB0QrbDwNmKg9  spotify:track:6qLQ0K5jkOB0QrbDwNmKg9
# 0  2n87qFKfPcqRPNfNH4TiAM  spotify:track:2n87qFKfPcqRPNfNH4TiAM
# 0  3QVa3D6QaQy0b0foOAYDuy  spotify:track:3QVa3D6QaQy0b0foOAYDuy
# 0  1cpmW4m6NVcAI33ZDEGwjZ  spotify:track:1cpmW4m6NVcAI33ZDEGwjZ
# 0  2XycvTajCfgJFNYDY1JVTG  spotify:track:2XycvTajCfgJFNYDY1JVTG
# 0  6DfZhqra01cpWIH5VluN2q  spotify:track:6DfZhqra01cpWIH5VluN2q
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1aXV8GrmQLvg...
# 0  https://api.spotify.com/v1/tracks/6RiiSy9GzSwi...
# 0  https://api.spotify.com/v1/tracks/7s5VQqrjBtrB...
# 0  https://api.spotify.com/v1/tracks/5HzrX4aKVfb1...
# 0  https://api.spotify.com/v1/tracks/6qLQ0K5jkOB0...
# 0  https://api.spotify.com/v1/tracks/2n87qFKfPcqR...
# 0  https://api.spotify.com/v1/tracks/3QVa3D6QaQy0...
# 0  https://api.spotify.com/v1/tracks/1cpmW4m6NVcA...
# 0  https://api.spotify.com/v1/tracks/2XycvTajCfgJ...
# 0  https://api.spotify.com/v1/tracks/6DfZhqra01cp...
#
#                                         analysis_url  duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1aXV...       122339
# 0  https://api.spotify.com/v1/audio-analysis/6Rii...       153313
# 0  https://api.spotify.com/v1/audio-analysis/7s5V...        86739
# 0  https://api.spotify.com/v1/audio-analysis/5Hzr...       168740
# 0  https://api.spotify.com/v1/audio-analysis/6qLQ...       127000
# 0  https://api.spotify.com/v1/audio-analysis/2n87...       176283
# 0  https://api.spotify.com/v1/audio-analysis/3QVa...       125085
# 0  https://api.spotify.com/v1/audio-analysis/1cpm...       157576
# 0  https://api.spotify.com/v1/audio-analysis/2Xyc...       227467
# 0  https://api.spotify.com/v1/audio-analysis/6DfZ...        98209
#
#    time_signature
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4
# 0               4

# %%
final_df = track_df.merge(features_df, left_on="Id", right_on="id")

# %%
final_df
# Out:
#    Item    Artist                 Album Name                      Id  \
# 0     0  Eyedress  Let's Skip to the Wedding  1aXV8GrmQLvgoFtBPERP7E
# 1     1  Eyedress  Let's Skip to the Wedding  6RiiSy9GzSwiyDEJDiMuKe
# 2     2  Eyedress  Let's Skip to the Wedding  7s5VQqrjBtrBgZL4pEa46S
# 3     3  Eyedress  Let's Skip to the Wedding  5HzrX4aKVfb1NQCsaqf6R0
# 4     4  Eyedress  Let's Skip to the Wedding  6qLQ0K5jkOB0QrbDwNmKg9
# 5     5  Eyedress  Let's Skip to the Wedding  2n87qFKfPcqRPNfNH4TiAM
# 6     6  Eyedress  Let's Skip to the Wedding  3QVa3D6QaQy0b0foOAYDuy
# 7     7  Eyedress  Let's Skip to the Wedding  1cpmW4m6NVcAI33ZDEGwjZ
# 8     8  Eyedress  Let's Skip to the Wedding  2XycvTajCfgJFNYDY1JVTG
# 9     9  Eyedress  Let's Skip to the Wedding  6DfZhqra01cpWIH5VluN2q
#
#                           Song Name Release Date  Popularity  danceability  \
# 0                           Jealous   2019-12-06          82         0.474
# 1               Something About You   2021-08-27          78         0.648
# 2                    Romantic Lover   2020-08-07          76         0.658
# 3                    Cocaine Sunday   2018-11-16          67         0.544
# 4                            On Fye   2022-02-14          62         0.484
# 5  Kiss Me Like It's the First Time   2020-08-07          58         0.636
# 6                   Body Dysmorphia   2021-08-27          58         0.495
# 7            Can I See You Tonight?   2020-08-07          57         0.444
# 8                Separation Anxiety   2017-05-12          56         0.423
# 9         Let's Skip to the Wedding   2020-08-07          55         0.454
#
#    energy  key  ...  liveness  valence    tempo            type  \
# 0   0.921    9  ...    0.4760    0.696   93.010  audio_features
# 1   0.781    9  ...    0.3050    0.822  133.417  audio_features
# 2   0.447    9  ...    0.1980    0.538  184.316  audio_features
# 3   0.765    4  ...    0.1500    0.429  153.916  audio_features
# 4   0.804    1  ...    0.2680    0.802   92.425  audio_features
# 5   0.593   11  ...    0.0454    0.223  113.007  audio_features
# 6   0.662   11  ...    0.1190    0.966  165.209  audio_features
# 7   0.615    9  ...    0.1150    0.613  197.880  audio_features
# 8   0.760    3  ...    0.1100    0.519  164.096  audio_features
# 9   0.966    9  ...    0.0580    0.643  148.210  audio_features
#
#                        id                                   uri  \
# 0  1aXV8GrmQLvgoFtBPERP7E  spotify:track:1aXV8GrmQLvgoFtBPERP7E
# 1  6RiiSy9GzSwiyDEJDiMuKe  spotify:track:6RiiSy9GzSwiyDEJDiMuKe
# 2  7s5VQqrjBtrBgZL4pEa46S  spotify:track:7s5VQqrjBtrBgZL4pEa46S
# 3  5HzrX4aKVfb1NQCsaqf6R0  spotify:track:5HzrX4aKVfb1NQCsaqf6R0
# 4  6qLQ0K5jkOB0QrbDwNmKg9  spotify:track:6qLQ0K5jkOB0QrbDwNmKg9
# 5  2n87qFKfPcqRPNfNH4TiAM  spotify:track:2n87qFKfPcqRPNfNH4TiAM
# 6  3QVa3D6QaQy0b0foOAYDuy  spotify:track:3QVa3D6QaQy0b0foOAYDuy
# 7  1cpmW4m6NVcAI33ZDEGwjZ  spotify:track:1cpmW4m6NVcAI33ZDEGwjZ
# 8  2XycvTajCfgJFNYDY1JVTG  spotify:track:2XycvTajCfgJFNYDY1JVTG
# 9  6DfZhqra01cpWIH5VluN2q  spotify:track:6DfZhqra01cpWIH5VluN2q
#
#                                           track_href  \
# 0  https://api.spotify.com/v1/tracks/1aXV8GrmQLvg...
# 1  https://api.spotify.com/v1/tracks/6RiiSy9GzSwi...
# 2  https://api.spotify.com/v1/tracks/7s5VQqrjBtrB...
# 3  https://api.spotify.com/v1/tracks/5HzrX4aKVfb1...
# 4  https://api.spotify.com/v1/tracks/6qLQ0K5jkOB0...
# 5  https://api.spotify.com/v1/tracks/2n87qFKfPcqR...
# 6  https://api.spotify.com/v1/tracks/3QVa3D6QaQy0...
# 7  https://api.spotify.com/v1/tracks/1cpmW4m6NVcA...
# 8  https://api.spotify.com/v1/tracks/2XycvTajCfgJ...
# 9  https://api.spotify.com/v1/tracks/6DfZhqra01cp...
#
#                                         analysis_url duration_ms  \
# 0  https://api.spotify.com/v1/audio-analysis/1aXV...      122339
# 1  https://api.spotify.com/v1/audio-analysis/6Rii...      153313
# 2  https://api.spotify.com/v1/audio-analysis/7s5V...       86739
# 3  https://api.spotify.com/v1/audio-analysis/5Hzr...      168740
# 4  https://api.spotify.com/v1/audio-analysis/6qLQ...      127000
# 5  https://api.spotify.com/v1/audio-analysis/2n87...      176283
# 6  https://api.spotify.com/v1/audio-analysis/3QVa...      125085
# 7  https://api.spotify.com/v1/audio-analysis/1cpm...      157576
# 8  https://api.spotify.com/v1/audio-analysis/2Xyc...      227467
# 9  https://api.spotify.com/v1/audio-analysis/6DfZ...       98209
#
#   time_signature
# 0              4
# 1              4
# 2              4
# 3              4
# 4              4
# 5              4
# 6              4
# 7              4
# 8              4
# 9              4
#
# [10 rows x 25 columns]

# %%
final_df_sorted = final_df.sort_values(by=['Popularity'], ascending=False)

# %%
feature_name = "danceability"

# %%
df_plot = final_df_sorted[['Artist', 'Album Name', 'Song Name', 'Release Date', 'Popularity', f'{feature_name}']]

# %%
df_plot
# Out:
#      Artist                 Album Name                         Song Name  \
# 0  Eyedress  Let's Skip to the Wedding                           Jealous
# 1  Eyedress  Let's Skip to the Wedding               Something About You
# 2  Eyedress  Let's Skip to the Wedding                    Romantic Lover
# 3  Eyedress  Let's Skip to the Wedding                    Cocaine Sunday
# 4  Eyedress  Let's Skip to the Wedding                            On Fye
# 5  Eyedress  Let's Skip to the Wedding  Kiss Me Like It's the First Time
# 6  Eyedress  Let's Skip to the Wedding                   Body Dysmorphia
# 7  Eyedress  Let's Skip to the Wedding            Can I See You Tonight?
# 8  Eyedress  Let's Skip to the Wedding                Separation Anxiety
# 9  Eyedress  Let's Skip to the Wedding         Let's Skip to the Wedding
#
#   Release Date  Popularity  danceability
# 0   2019-12-06          82         0.474
# 1   2021-08-27          78         0.648
# 2   2020-08-07          76         0.658
# 3   2018-11-16          67         0.544
# 4   2022-02-14          62         0.484
# 5   2020-08-07          58         0.636
# 6   2021-08-27          58         0.495
# 7   2020-08-07          57         0.444
# 8   2017-05-12          56         0.423
# 9   2020-08-07          55         0.454

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
plt.figure(figsize=(15, 6), facecolor=(.9, .9, .9))
    
x = df_plot['Song Name']
y = df_plot[feature_name]
s = df_plot['Popularity']*10
    
# color_labels = reco_df['explicit'].unique()
# rgb_values = sns.color_palette("Set1", 8)
# color_map = dict(zip(color_labels, rgb_values))

plt.scatter(x, y, s, alpha=0.7, c=df_plot[feature_name])
plt.xticks(rotation=90)
plt.legend()
# show the graph
plt.show()
# Out:
# No handles with labels found to put in legend.

# %%
#pip install altair
pip show altair
# Out:
# Name: altair
# Version: 4.2.0
# Summary: Altair: A declarative statistical visualization library for Python.
# Home-page: http://altair-viz.github.io
# Author: Brian E. Granger / Jake VanderPlas
# Author-email: jakevdp@gmail.com
# License: BSD 3-clause
# Location: c:\users\mirey\anaconda3\lib\site-packages
# Requires: jsonschema, pandas, numpy, jinja2, toolz, entrypoints
# Required-by:
# Note: you may need to restart the kernel to use updated packages.

# %%
import altair as alt

# %%
alt.Chart(df_plot).mark_circle().encode(
alt.X('Popularity', scale=alt.Scale(zero=False)), y=f'{feature_name}', color=alt.Color('Popularity', scale=alt.Scale(zero=False)), 
size=alt.value(200), tooltip=['Popularity', f'{feature_name}', 'Song Name', 'Album Name'])
# Out:
# alt.Chart(...)
